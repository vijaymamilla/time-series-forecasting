# %% [markdown]
# # Install Pandas Data Reader

# %%
# !pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from pandas-datareader) (2.28.1)
# Requirement already satisfied: pandas>=0.23 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from pandas-datareader) (1.4.4)
# Requirement already satisfied: lxml in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas-datareader) (1.21.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: six>=1.5 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0

# %%
import pandas_datareader as pdr

# %%
import pandas as pd

# %%
from datetime import datetime

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.20-py2.py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.4 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: requests>=2.26 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: html5lib>=1.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (37.0.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=1.3.0 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Collecting pytz>=2022.5
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.8-cp39-cp39-macosx_10_9_x86_64.whl (36 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: pycparser in /Users/hadoop/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: pytz, multitasking, frozendict, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# Successfully installed frozendict-2.3.8 multitasking-0.0.11 pytz-2023.3 yfinance-0.2.20

# %%
import yfinance as yf
df_tesla = yf.download('TSLA', start = '2020-01-01', end='2023-06-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-24  182.229996  184.220001  178.220001  182.899994  182.899994
# 2023-05-25  186.539993  186.779999  180.580002  184.470001  184.470001
# 2023-05-26  184.619995  198.600006  184.529999  193.169998  193.169998
# 2023-05-30  200.100006  204.479996  197.529999  201.160004  201.160004
# 2023-05-31  199.779999  203.949997  195.119995  203.929993  203.929993
#
#                Volume
# Date
# 2023-05-24  137605100
# 2023-05-25   96870700
# 2023-05-26  162061500
# 2023-05-30  128818700
# 2023-05-31  150711700

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,300],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-22',
#                '2023-05-23', '2023-05-24', '2023-05-25', '2023-05-26',
#                '2023-05-30', '2023-05-31'],
#               dtype='datetime64[ns]', name='Date', length=859, freq=None)

# %%
df_tesla.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
